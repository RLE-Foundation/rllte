# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data_path = "../logs"
exps = os.listdir(data_path)
results = {}

for exp in exps:
    try:
        nested_ = os.listdir(os.path.join(data_path, exp))
        file = os.path.join(data_path, exp, nested_[0], "train.log")
        data = pd.read_csv(file)

        # take all but last _s1, or _s2, or _s3 which are the seeds
        exp_name = "_".join(exp.split("_")[:-1])
        if exp_name not in results:
            results[exp_name] = []
        
        results[exp_name].append(data["episode_reward"])
    except Exception as e:
        print(f"Error with {exp, e}")
        continue

# %%
# lets get the mean performance of the extrinsic agent. for the key that contains "extrinsic" compute mean and pop key 
extrinsic_performance = []
keys_to_pop = []
for key in results.keys():
    if "extrinsic" in key:
        # compute the mean for the last 100 episodes
        mean = np.mean([np.mean(x[-100:]) for x in results[key]])
        extrinsic_performance.append(mean)
        keys_to_pop.append(key)

# for key in keys_to_pop:
#    results.pop(key)

# plot the extrinsic curve
print(extrinsic_performance)
# Out:
# [0.6300010005980731]

# %%
# make sure for each key in results, all the lists of rewards in the key are of the same length (which should be the max length common to all)
min_lens = {}
for key in results:
    min_len = min([len(x) for x in results[key]])
    results[key] = [x[:min_len] for x in results[key]]
    min_lens[key] = min_len
    print(f"Key {key} has {len(results[key])} runs of length {min_len}")
# Out:
# Key PPO_MiniGrid-FourRooms-v0_icm_obsRMS:False_rewNorm:rms_updateProp:0.25_weightInit:orthogonal has 1 runs of length 610
# Key PPO_MiniGrid-FourRooms-v0_e3b_obsRMS:False_rewNorm:rms_updateProp:0.25_weightInit:orthogonal has 1 runs of length 500
# Key PPO_MiniGrid-FourRooms-v0_pseudocounts_obsRMS:True_rewNorm:rms_updateProp:0.25_weightInit:orthogonal has 1 runs of length 610
# Key PPO_MiniGrid-FourRooms-v0_ngu_obsRMS:True_rewNorm:rms_updateProp:0.25_weightInit:orthogonal has 1 runs of length 610
# Key PPO_MiniGrid-FourRooms-v0_ngu_obsRMS:False_rewNorm:rms_updateProp:0.25_weightInit:orthogonal has 1 runs of length 610
# Key PPO_MiniGrid-FourRooms-v0_e3b_obsRMS:True_rewNorm:rms_updateProp:0.25_weightInit:orthogonal has 1 runs of length 610
# Key PPO_MiniGrid-FourRooms-v0_icm_obsRMS:True_rewNorm:rms_updateProp:0.25_weightInit:orthogonal has 1 runs of length 610
# Key PPO_MiniGrid-FourRooms-v0_re3_obsRMS:False_rewNorm:rms_updateProp:0.25_weightInit:orthogonal has 1 runs of length 610
# Key PPO_MiniGrid-FourRooms-v0_ride_obsRMS:True_rewNorm:rms_updateProp:0.25_weightInit:orthogonal has 1 runs of length 610
# Key PPO_MiniGrid-FourRooms-v0_extrinsic_obsRMS:False_rewNorm:rms_updateProp:0.25_weightInit:orthogonal has 1 runs of length 610
# Key PPO_MiniGrid-FourRooms-v0_pseudocounts_obsRMS:False_rewNorm:rms_updateProp:0.25_weightInit:orthogonal has 1 runs of length 610
# Key PPO_MiniGrid-FourRooms-v0_ride_obsRMS:False_rewNorm:rms_updateProp:0.25_weightInit:orthogonal has 1 runs of length 610
# Key PPO_MiniGrid-FourRooms-v0_rnd_obsRMS:False_rewNorm:rms_updateProp:0.25_weightInit:orthogonal has 1 runs of length 610
# Key PPO_MiniGrid-FourRooms-v0_rnd_obsRMS:True_rewNorm:rms_updateProp:0.25_weightInit:orthogonal has 1 runs of length 610
# Key PPO_MiniGrid-FourRooms-v0_re3_obsRMS:True_rewNorm:rms_updateProp:0.25_weightInit:orthogonal has 1 runs of length 610

# %%
# plot 11 subplots
fig, axs = plt.subplots(3, 4, figsize=(15, 7))
axs = axs.ravel()

for i, key in enumerate(results):
    try:
        mean = np.mean(results[key], axis=0)
        std = np.std(results[key], axis=0)
        
        # append 0s to the beginning so that they start in the same place
        mean = np.append(np.zeros(10), mean)
        std = np.append(np.zeros(10), std)

        # smooth with np.convolve
        window = 10
        mean = np.convolve(mean, np.ones(window), 'valid') / window
        std = np.convolve(std, np.ones(window), 'valid') / window
        
        x = np.arange(len(mean))

        # plot line at the extrinsic performance
        axs[i].axhline(y=np.mean(extrinsic_performance), color="r", linestyle="--")

        algo_name = key.split("_")[2]

        axs[i].fill_between(x, mean - std, mean + std, alpha=0.3)
        axs[i].plot(x, mean)
        # y limit from 0 to 3500
        #axs[i].set_ylim([-10, 35])
        axs[i].set_title(algo_name.upper())
        axs[i].set_xlabel("Episodes")
        axs[i].set_ylabel("Reward")
    except:
        print(f"Error with {key}")
        continue
plt.tight_layout()
# Out:
# Error with PPO_MiniGrid-FourRooms-v0_rnd_obsRMS:False_rewNorm:rms_updateProp:0.25_weightInit:orthogonal
# Error with PPO_MiniGrid-FourRooms-v0_rnd_obsRMS:True_rewNorm:rms_updateProp:0.25_weightInit:orthogonal
# Error with PPO_MiniGrid-FourRooms-v0_re3_obsRMS:True_rewNorm:rms_updateProp:0.25_weightInit:orthogonal
